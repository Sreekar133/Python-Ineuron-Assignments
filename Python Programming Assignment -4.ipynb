# %%
#Write a Python Program to Find the Factorial of a Number?
n = int(input("enter the number for the factorial"))
count=1
for i in range(1,n+1):
    count = count*i
print("the factorial of", n , "is" , count)
# Out:
# enter the number for the factorial6
# the factorial of 6 is 720

# %%
#Write a Python Program to Display the multiplication Table?
n = int(input("enter the number for the multiplication table you require"))
a = int(input("enter the number to which limit you require the table"))
for i in range(1,a+1):
        k = n*i
        print(n,"*",i,"=",k)
# Out:
# enter the number for the multiplication table you require10
# enter the number to which limit you require the table20
# 10 * 1 = 10
# 10 * 2 = 20
# 10 * 3 = 30
# 10 * 4 = 40
# 10 * 5 = 50
# 10 * 6 = 60
# 10 * 7 = 70
# 10 * 8 = 80
# 10 * 9 = 90
# 10 * 10 = 100
# 10 * 11 = 110
# 10 * 12 = 120
# 10 * 13 = 130
# 10 * 14 = 140
# 10 * 15 = 150
# 10 * 16 = 160
# 10 * 17 = 170
# 10 * 18 = 180
# 10 * 19 = 190
# 10 * 20 = 200

# %%
#write a Python Program to Print the Fibonacci sequence?

n = int(input("enter the number to which you require the fibonacii series"))
a = 0
b = 1
for i in range(0,n+1):
    print("index is", i,  "and its fiboncaii is",a )
    a,b = b,a+b
# Out:
# enter the number to which you require the fibonacii series9
# index is 0 and its fiboncaii is 0
# index is 1 and its fiboncaii is 1
# index is 2 and its fiboncaii is 1
# index is 3 and its fiboncaii is 2
# index is 4 and its fiboncaii is 3
# index is 5 and its fiboncaii is 5
# index is 6 and its fiboncaii is 8
# index is 7 and its fiboncaii is 13
# index is 8 and its fiboncaii is 21
# index is 9 and its fiboncaii is 34

# %%
#Write a Python Program to Check Armstrong Number?
n = int(input("enter the number"))
sum = 0
temp = n

while temp > 0:
    digit = temp%10
    sum = sum+digit**3
    temp = temp//10
    
if n == sum:
    print("it is a armstrong number")
else:
    print("it is not a armstrong number")
# Out:
# enter the number371
# it is a armstrong number

# %%
#Write a Python Program to Find Armstrong Number in an Interval?
n = int(input("enter the interval"))
for i in range(0,n+1):
    temp = i
    sum=0
    while temp > 0:
        digit = temp%10
        sum = sum+digit**3
        temp = temp//10
    if i == sum:
        print(i ,"it is a armstrong number")
    else:
        print(i,"it is not a armstrong number")
# Out:
# enter the number154
# 0 it is a armstrong number
# 1 it is a armstrong number
# 2 it is not a armstrong number
# 3 it is not a armstrong number
# 4 it is not a armstrong number
# 5 it is not a armstrong number
# 6 it is not a armstrong number
# 7 it is not a armstrong number
# 8 it is not a armstrong number
# 9 it is not a armstrong number
# 10 it is not a armstrong number
# 11 it is not a armstrong number
# 12 it is not a armstrong number
# 13 it is not a armstrong number
# 14 it is not a armstrong number
# 15 it is not a armstrong number
# 16 it is not a armstrong number
# 17 it is not a armstrong number
# 18 it is not a armstrong number
# 19 it is not a armstrong number
# 20 it is not a armstrong number
# 21 it is not a armstrong number
# 22 it is not a armstrong number
# 23 it is not a armstrong number
# 24 it is not a armstrong number
# 25 it is not a armstrong number
# 26 it is not a armstrong number
# 27 it is not a armstrong number
# 28 it is not a armstrong number
# ...

# %%
#rite a Python Program to Find the Sum of Natural Numbers?

n = int(input("enter the upper limit to add the sum of numbers"))

a =  n*(n+1)
b=a/2
print("sum of natural numbers of", n ,"is",b)
# Out:
# enter the upper limit to add the sum of numbers11
# sum of natural numbers of 11 is 66.0
